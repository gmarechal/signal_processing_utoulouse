# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr

# %%
ds_satellite = xr.open_dataset('./data/S2_imag.nc')

# %%
min_longitude, max_longitude = 331, 332
min_latitude, max_latitude =  39, 38

# %%
185310/27830
# Out:
# 6.658641753503414

# %%
120/6.6
# Out:
# 18.181818181818183

# %%
sub_image = ds_satellite.B02_10m.sel(longitude = slice(min_longitude, max_longitude), latitude = slice(min_latitude, max_latitude))

# %%
(sub_image*scale_factor).plot()
